# %% [markdown]
# ![](ITD.png)
#
# <div style = " Text-align: center">
#
# # Inteligencia Artificial
#
# ##  titanic(Arboles de Decision)
#
# ### Nombre Del Docente
# ## Rodriguez Rivas Jose Gabriel
# ### Nombre Del Alumno
# ## Edgar Miguel Soto Trujillo
#
# </div>

# %% [markdown]
# ### practica
# En este  laboratorio devo  crear un clasificador de árbol de decisiones que funcione con un conjunto de datos que contenga los  detalles sobre los pasajeros que estaban a bordo del trasatlántico Titanic durante su trágico primer viaje cuantos fallecieron y cque tipo de pase tenenian.

# %% [markdown]
# ### parte 1

# %%
#import pandas
import pandas as pd

#create a pandas dataframe called "training" from the titanic-train.csv file
training = pd.read_csv("titanic-train.csv")

# %%
training.head()
# Out:
#    PassengerId  Survived  Pclass                         Name  Gender   Age  \
# 0            1         0       1       Davidson, Mr. Thornton    male  31.0
# 1            2         0       3              Asim, Mr. Adola    male  35.0
# 2            3         0       3           Nankoff, Mr. Minko    male   NaN
# 3            4         0       1     Thayer, Mr. John Borland    male  49.0
# 4            5         0       3  Strandberg, Miss. Ida Sofia  female  22.0
#
#    SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      1      0          F.C. 12750   52.0000   B71        S
# 1      0      0  SOTON/O.Q. 3101310    7.0500   NaN        S
# 2      0      0              349218    7.8958   NaN        S
# 3      1      1               17421  110.8833   C68        C
# 4      0      0                7553    9.8375   NaN        S

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 12 columns):
# PassengerId    915 non-null int64
# Survived       915 non-null int64
# Pclass         915 non-null int64
# Name           915 non-null object
# Gender         915 non-null object
# Age            738 non-null float64
# SibSp          915 non-null int64
# Parch          915 non-null int64
# Ticket         915 non-null object
# Fare           915 non-null float64
# Cabin          202 non-null object
# Embarked       914 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 85.9+ KB

# %% [markdown]
# ¿Faltan valores en el conjunto de datos?
#
# **Respuesta:** Si hay valores nulos en el caso de la edad y la cabina.

# %% [markdown]
# ### Paso 2: Preparar los datos para el modelo de árbol de decisiones

# %%
training["Gender"] = training["Gender"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
training.head()
# Out:
#    PassengerId  Survived  Pclass                         Name  Gender   Age  \
# 0            1         0       1       Davidson, Mr. Thornton       0  31.0
# 1            2         0       3              Asim, Mr. Adola       0  35.0
# 2            3         0       3           Nankoff, Mr. Minko       0   NaN
# 3            4         0       1     Thayer, Mr. John Borland       0  49.0
# 4            5         0       3  Strandberg, Miss. Ida Sofia       1  22.0
#
#    SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      1      0          F.C. 12750   52.0000   B71        S
# 1      0      0  SOTON/O.Q. 3101310    7.0500   NaN        S
# 2      0      0              349218    7.8958   NaN        S
# 3      1      1               17421  110.8833   C68        C
# 4      0      0                7553    9.8375   NaN        S

# %%
training["Age"].fillna(training["Age"].mean(), inplace=True)

# %%
training
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       1
# 1              2         0       3
# 2              3         0       3
# 3              4         0       1
# 4              5         0       3
# 5              6         0       2
# 6              7         0       3
# 7              8         0       3
# 8              9         0       3
# 9             10         0       3
# 10            11         0       3
# 11            12         0       2
# 12            13         1       1
# 13            14         1       1
# 14            15         0       3
# 15            16         1       3
# 16            17         0       2
# 17            18         1       1
# 18            19         0       3
# 19            20         1       3
# 20            21         0       3
# 21            22         1       3
# 22            23         1       1
# 23            24         0       3
# 24            25         0       3
# 25            26         1       1
# 26            27         1       2
# 27            28         0       3
# 28            29         0       3
# 29            30         1       3
# ..           ...       ...     ...
# 885          886         0       1
# 886          887         0       2
# 887          888         0       1
# 888          889         0       3
# 889          890         1       3
# 890          891         0       3
# 891          892         0       3
# 892          893         1       1
# 893          894         0       3
# 894          895         0       2
# 895          896         1       1
# 896          897         1       3
# 897          898         0       3
# 898          899         1       2
# 899          900         1       1
# 900          901         1       3
# 901          902         0       3
# 902          903         0       3
# 903          904         0       3
# 904          905         1       1
# 905          906         1       1
# 906          907         1       3
# 907          908         0       2
# 908          909         0       1
# 909          910         0       3
# 910          911         0       3
# 911          912         0       1
# 912          913         0       3
# 913          914         0       3
# 914          915         0       3
#
#                                                Name  Gender        Age  SibSp  \
# 0                            Davidson, Mr. Thornton       0  31.000000      1
# 1                                   Asim, Mr. Adola       0  35.000000      0
# 2                                Nankoff, Mr. Minko       0  29.970867      0
# 3                          Thayer, Mr. John Borland       0  49.000000      1
# 4                       Strandberg, Miss. Ida Sofia       1  22.000000      0
# 5                              Bowenur, Mr. Solomon       0  42.000000      0
# 6                       Bowen, Mr. David John "Dai"       0  21.000000      0
# 7                                    Assam, Mr. Ali       0  23.000000      0
# 8                                  Thomas, Mr. John       0  29.970867      0
# 9                               Moran, Mr. Daniel J       0  29.970867      1
# 10                               Lahoud, Mr. Sarkis       0  29.970867      0
# 11                        Maybery, Mr. Frank Hubert       0  40.000000      0
# 12                  Greenfield, Mr. William Bertram       0  23.000000      0
# 13    Snyder, Mrs. John Pillsbury (Nelle Stevenson)       1  23.000000      1
# 14                                  Mahon, Mr. John       0  29.970867      0
# 15                                 Nakid, Mr. Sahid       0  20.000000      1
# 16                        Stokes, Mr. Philip Joseph       0  25.000000      0
# 17   Lines, Mrs. Ernest H (Elizabeth Lindsey James)       1  51.000000      0
# 18                                  Flynn, Mr. John       0  29.970867      0
# 19                    O'Leary, Miss. Hanora "Norah"       1  29.970867      0
# 20                             Zabour, Miss. Hileni       1  14.500000      1
# 21                                  Chip, Mr. Chang       0  32.000000      0
# 22                             Cleaver, Miss. Alice       1  22.000000      0
# 23                              Canavan, Miss. Mary       1  21.000000      0
# 24                          Moen, Mr. Sigurd Hansen       0  25.000000      0
# 25                        Harper, Mr. Henry Sleeper       0  48.000000      1
# 26                       Quick, Miss. Winifred Vera       1   8.000000      1
# 27                        Rice, Master. George Hugh       0   8.000000      4
# 28                     Berglund, Mr. Karl Ivar Sven       0  22.000000      0
# 29                   Murphy, Miss. Katherine "Kate"       1  29.970867      1
# ..                                              ...     ...        ...    ...
# 885                        Julian, Mr. Henry Forbes       0  50.000000      0
# 886                       Myles, Mr. Thomas Francis       0  62.000000      0
# 887                    McCaffry, Mr. Thomas Francis       0  46.000000      0
# 888                               Kink, Mr. Vincenz       0  26.000000      2
# 889                      Aks, Mrs. Sam (Leah Rosen)       1  18.000000      0
# 890                                 Cor, Mr. Bartol       0  35.000000      0
# 891       Khalil, Mrs. Betros (Zahie "Maria" Elias)       1  29.970867      1
# 892                            Marechal, Mr. Pierre       0  29.970867      0
# 893                         Boulos, Miss. Nourelain       1   9.000000      1
# 894               Byles, Rev. Thomas Roussel Davids       0  42.000000      0
# 895                     Compton, Miss. Sara Rebecca       1  39.000000      1
# 896                        Kink-Heilmann, Mr. Anton       0  29.000000      3
# 897    Riihivouri, Miss. Susanna Juhantytar "Sanni"       1  22.000000      0
# 898             Troutt, Miss. Edwina Celia "Winnie"       1  27.000000      0
# 899                 Schabert, Mrs. Paul (Emma Mock)       1  35.000000      1
# 900       Davison, Mrs. Thomas Henry (Mary E Finck)       1  29.970867      1
# 901                             Yasbeck, Mr. Antoni       0  27.000000      1
# 902  Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)       1  36.000000      0
# 903                        Larsson, Mr. Bengt Edvin       0  29.000000      0
# 904                    Hoyt, Mr. Frederick Maxfield       0  38.000000      1
# 905                          Lesurer, Mr. Gustave J       0  35.000000      0
# 906                            O'Keefe, Mr. Patrick       0  29.970867      0
# 907                   Fillbrook, Mr. Joseph Charles       0  18.000000      0
# 908                       Crafton, Mr. John Bertram       0  29.970867      0
# 909                        Crease, Mr. Ernest James       0  19.000000      0
# 910                             Baccos, Mr. Raffull       0  20.000000      0
# 911                      Smith, Mr. Richard William       0  29.970867      0
# 912                                Wirz, Mr. Albert       0  27.000000      0
# 913                             Johnson, Mr. Alfred       0  49.000000      0
# 914                                Fox, Mr. Patrick       0  29.970867      0
#
#      Parch              Ticket      Fare    Cabin Embarked
# 0        0          F.C. 12750   52.0000      B71        S
# 1        0  SOTON/O.Q. 3101310    7.0500      NaN        S
# 2        0              349218    7.8958      NaN        S
# 3        1               17421  110.8833      C68        C
# 4        0                7553    9.8375      NaN        S
# 5        0              211535   13.0000      NaN        S
# 6        0               54636   16.1000      NaN        S
# 7        0  SOTON/O.Q. 3101309    7.0500      NaN        S
# 8        0                2681    6.4375      NaN        C
# 9        0              371110   24.1500      NaN        Q
# 10       0                2624    7.2250      NaN        C
# 11       0              239059   16.0000      NaN        S
# 12       1            PC 17759   63.3583  D10 D12        C
# 13       0               21228   82.2667      B45        S
# 14       0           AQ/4 3130    7.7500      NaN        Q
# 15       1                2653   15.7417      NaN        C
# 16       0        F.C.C. 13540   10.5000      NaN        S
# 17       1            PC 17592   39.4000      D28        S
# 18       0              368323    6.9500      NaN        Q
# 19       0              330919    7.8292      NaN        Q
# 20       0                2665   14.4542      NaN        C
# 21       0                1601   56.4958      NaN        S
# 22       0              113781  151.5500      NaN        S
# 23       0              364846    7.7500      NaN        Q
# 24       0              348123    7.6500    F G73        S
# 25       0            PC 17572   76.7292      D33        C
# 26       1               26360   26.0000      NaN        S
# 27       1              382652   29.1250      NaN        Q
# 28       0             PP 4348    9.3500      NaN        S
# 29       0              367230   15.5000      NaN        Q
# ..     ...                 ...       ...      ...      ...
# 885      0              113044   26.0000      E60        S
# 886      0              240276    9.6875      NaN        Q
# 887      0               13050   75.2417       C6        C
# 888      0              315151    8.6625      NaN        S
# 889      1              392091    9.3500      NaN        S
# 890      0              349230    7.8958      NaN        S
# 891      0                2660   14.4542      NaN        C
# 892      0               11774   29.7000      C47        C
# 893      1                2678   15.2458      NaN        C
# 894      0              244310   13.0000      NaN        S
# 895      1            PC 17756   83.1583      E49        C
# 896      1              315153   22.0250      NaN        S
# 897      0             3101295   39.6875      NaN        S
# 898      0               34218   10.5000     E101        S
# 899      0               13236   57.7500      C28        C
# 900      0              386525   16.1000      NaN        S
# 901      0                2659   14.4542      NaN        C
# 902      2              350405   12.1833      NaN        S
# 903      0              347067    7.7750      NaN        S
# 904      0               19943   90.0000      C93        S
# 905      0            PC 17755  512.3292     B101        C
# 906      0              368402    7.7500      NaN        Q
# 907      0          C.A. 15185   10.5000      NaN        S
# 908      0              113791   26.5500      NaN        S
# 909      0           S.P. 3464    8.1583      NaN        S
# 910      0                2679    7.2250      NaN        C
# 911      0              113056   26.0000      A19        S
# 912      0              315154    8.6625      NaN        S
# 913      0                LINE    0.0000      NaN        S
# 914      0              368573    7.7500      NaN        Q
#
# [915 rows x 12 columns]

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 12 columns):
# PassengerId    915 non-null int64
# Survived       915 non-null int64
# Pclass         915 non-null int64
# Name           915 non-null object
# Gender         915 non-null int64
# Age            915 non-null float64
# SibSp          915 non-null int64
# Parch          915 non-null int64
# Ticket         915 non-null object
# Fare           915 non-null float64
# Cabin          202 non-null object
# Embarked       914 non-null object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 85.9+ KB

# %% [markdown]
# ¿Cuál es el valor que se utilizó para reemplazar a las edades faltantes?
#
# **Respuesta:** 29

# %% [markdown]
# ### Paso 3: Entrenar y calificar el modelo del árbol de decisiones.

# %%
#create the array for the target values
y_target = training["Survived"].values

# %%
columns = ["Fare", "Pclass", "Gender", "Age", "SibSp"]
#create the variable to hold the features that the classifier will use
X_input = training[list(columns)].values

# %%
#import the tree module from the sklearn library
from sklearn import tree

#create clf_train as a decision tree classifier object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)

#train the model using the fit() method of the decision tree object. 
#Supply the method with the input variable X_input and the target variable y_target
clf_train = clf_train.fit(X_input, y_target)

# %% [markdown]
# #### Evalúe el modelo.
# Utilice el método score() del objeto del árbol de decisiones para mostrar la precisión del porcentaje de las asignaciones realizadas por el clasificador. Este método considera las variables de entrada y salida como argumentos.

# %%
clf_train.score(X_input,y_target)
# Out:
# 0.8163934426229508

# %% [markdown]
# #### Visualizar el árbol

# %%
clasificacion=['No Sobrevive', 'Sobrevive']

# %%
import sklearn
#from sklearn.externals.six import StringIO
with open("titanic.dot", 'w') as f:
  f = tree.export_graphviz(clf_train, out_file=f, feature_names=columns, class_names=clasificacion)

# %%
# !dot -Tpng titanic.dot -o titanic.png

# %%
from IPython.display import Image

#display the decison tree graphic
Image("titanic.png")

# %% [markdown]
# ¿Qué describe al grupo que tenía mayor cantidad de víctimas fatales? ¿Qué grupo tenía la mayor cantidad de sobrevivientes?
#
# La mayor de cantidad de victimas fatales tenian una cantidad baja de tarifa abonada por ticket  por eso era considerada
# la edad influia tambien los menores  para aser enfacis en su edad

# %% [markdown]
# ### Parte 2: Aplicar el modelo del árbol de decisiones

# %%
testing = pd.read_csv("titanic-test.csv")
testing
# Out:
#      PassengerId  Survived  Pclass  \
# 0            916         0       2
# 1            917         1       1
# 2            918         0       3
# 3            919         1       1
# 4            920         1       3
# 5            921         0       3
# 6            922         0       3
# 7            923         0       3
# 8            924         0       3
# 9            925         0       2
# 10           926         0       3
# 11           927         0       1
# 12           928         1       3
# 13           929         1       3
# 14           930         0       3
# 15           931         1       3
# 16           932         0       2
# 17           933         1       3
# 18           934         0       3
# 19           935         0       3
# 20           936         0       3
# 21           937         0       3
# 22           938         0       3
# 23           939         1       3
# 24           940         0       3
# 25           941         1       3
# 26           942         0       3
# 27           943         1       2
# 28           944         1       3
# 29           945         0       3
# ..           ...       ...     ...
# 363         1279         1       1
# 364         1280         1       1
# 365         1281         0       1
# 366         1282         0       3
# 367         1283         0       2
# 368         1284         0       3
# 369         1285         0       3
# 370         1286         0       2
# 371         1287         1       3
# 372         1288         0       1
# 373         1289         1       3
# 374         1290         1       1
# 375         1291         0       2
# 376         1292         1       1
# 377         1293         0       3
# 378         1294         1       1
# 379         1295         0       3
# 380         1296         0       3
# 381         1297         0       1
# 382         1298         0       3
# 383         1299         0       3
# 384         1300         0       3
# 385         1301         0       3
# 386         1302         1       2
# 387         1303         1       3
# 388         1304         0       3
# 389         1305         0       3
# 390         1306         1       1
# 391         1307         0       3
# 392         1308         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 0                      Coleridge, Mr. Reginald Charles    male  29.0      0
# 1    Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.0      1
# 2                                  Windelov, Mr. Einar    male  21.0      0
# 3                               Minahan, Miss. Daisy E  female  33.0      1
# 4                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 5                          Abbott, Mr. Rossmore Edward    male  16.0      1
# 6                            Karlsson, Mr. Nils August    male  22.0      0
# 7                              Connaghton, Mr. Michael    male  31.0      0
# 8                                   Foley, Mr. William    male   NaN      0
# 9                    Leyson, Mr. Robert William Norman    male  24.0      0
# 10                      Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 11                                  Brandeis, Mr. Emil    male  48.0      0
# 12                             de Mulder, Mr. Theodore    male  30.0      0
# 13                             Turja, Miss. Anna Sofia  female  18.0      0
# 14                             Ford, Mr. Edward Watson    male  18.0      2
# 15                                    Osman, Mrs. Mara  female  31.0      0
# 16                                   Lingane, Mr. John    male  61.0      0
# 17                      Touma, Master. Georges Youssef    male   7.0      1
# 18                         Van Impe, Mr. Jean Baptiste    male  36.0      1
# 19                              Johnston, Mr. Andrew G    male   NaN      1
# 20                         Chronopoulos, Mr. Demetrios    male  18.0      1
# 21                                   Badt, Mr. Mohamed    male  40.0      0
# 22             Rasmussen, Mrs. (Lena Jacobsen Solvang)  female   NaN      0
# 23        de Messemaeker, Mrs. Guillaume Joseph (Emma)  female  36.0      1
# 24                                   Samaan, Mr. Elias    male   NaN      2
# 25                              Turkula, Mrs. (Hedwig)  female  63.0      0
# 26                              Augustsson, Mr. Albert    male  23.0      0
# 27                                   Davis, Miss. Mary  female  28.0      0
# 28          Hansen, Mrs. Claus Peter (Jennie L Howard)  female  45.0      1
# 29                            Jussila, Miss. Mari Aina  female  21.0      1
# ..                                                 ...     ...   ...    ...
# 363                     Gibson, Miss. Dorothy Winifred  female  22.0      0
# 364                             Salomon, Mr. Abraham L    male   NaN      0
# 365                       Nicholson, Mr. Arthur Ernest    male  64.0      0
# 366                            Mardirosian, Mr. Sarkis    male   NaN      0
# 367                            Chapman, Mr. John Henry    male  37.0      1
# 368                                Thomas, Mr. Tannous    male   NaN      0
# 369                                   Davies, Mr. Evan    male  22.0      0
# 370                        Hickman, Mr. Stanley George    male  21.0      2
# 371                               Ayoub, Miss. Banoura  female  13.0      0
# 372                              Cairns, Mr. Alexander    male   NaN      0
# 373                                 Niskanen, Mr. Juha    male  39.0      0
# 374                              Maioni, Miss. Roberta  female  16.0      0
# 375                        Givard, Mr. Hans Kristensen    male  30.0      0
# 376  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  female  48.0      1
# 377                       Panula, Master. Urho Abraham    male   2.0      4
# 378       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.0      1
# 379                               Naidenoff, Mr. Penko    male  22.0      0
# 380                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 381                            Smith, Mr. James Clinch    male  56.0      0
# 382                            Emir, Mr. Farred Chehab    male   NaN      0
# 383                                  Lester, Mr. James    male  39.0      0
# 384                   Gronnestad, Mr. Daniel Danielsen    male  32.0      0
# 385                        van Melkebeke, Mr. Philemon    male   NaN      0
# 386                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 387                          Mulvihill, Miss. Bertha E  female  24.0      0
# 388                              Thomas, Mr. Charles P    male   NaN      1
# 389                                Paulner, Mr. Uscher    male   NaN      0
# 390                     Thorne, Mrs. Gertrude Maybelle  female   NaN      0
# 391                          Holthen, Mr. Johan Martin    male  28.0      0
# 392               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
#
#      Parch             Ticket      Fare  Cabin Embarked
# 0        0        W./C. 14263   10.5000    NaN        S
# 1        1              16966  134.5000    E34        C
# 2        0   SOTON/OQ 3101317    7.2500    NaN        S
# 3        0              19928   90.0000    C78        Q
# 4        0             363272    7.0000    NaN        S
# 5        1          C.A. 2673   20.2500    NaN        S
# 6        0             350060    7.5208    NaN        S
# 7        0             335097    7.7500    NaN        Q
# 8        0             365235    7.7500    NaN        Q
# 9        0         C.A. 29566   10.5000    NaN        S
# 10       0             347086    7.7750    NaN        S
# 11       0           PC 17591   50.4958    B10        C
# 12       0             345774    9.5000    NaN        S
# 13       0               4138    9.8417    NaN        S
# 14       2         W./C. 6608   34.3750    NaN        S
# 15       0             349244    8.6833    NaN        S
# 16       0             235509   12.3500    NaN        Q
# 17       1               2650   15.2458    NaN        C
# 18       1             345773   24.1500    NaN        S
# 19       2         W./C. 6607   23.4500    NaN        S
# 20       0               2680   14.4542    NaN        C
# 21       0               2623    7.2250    NaN        C
# 22       0              65305    8.1125    NaN        S
# 23       0             345572   17.4000    NaN        S
# 24       0               2662   21.6792    NaN        C
# 25       0               4134    9.5875    NaN        S
# 26       0             347468    7.8542    NaN        S
# 27       0             237668   13.0000    NaN        S
# 28       0             350026   14.1083    NaN        S
# 29       0               4137    9.8250    NaN        S
# ..     ...                ...       ...    ...      ...
# 363      1             112378   59.4000    NaN        C
# 364      0             111163   26.0000    NaN        S
# 365      0                693   26.0000    NaN        S
# 366      0               2655    7.2292  F E46        C
# 367      0        SC/AH 29037   26.0000    NaN        S
# 368      0               2684    7.2250    NaN        C
# 369      0        SC/A4 23568    8.0500    NaN        S
# 370      0       S.O.C. 14879   73.5000    NaN        S
# 371      0               2687    7.2292    NaN        C
# 372      0             113798   31.0000    NaN        S
# 373      0  STON/O 2. 3101289    7.9250    NaN        S
# 374      0             110152   86.5000    B79        S
# 375      0             250646   13.0000    NaN        S
# 376      1              13567   79.2000    B41        C
# 377      1            3101295   39.6875    NaN        S
# 378      0           PC 17485   56.9292    A20        C
# 379      0             349206    7.8958    NaN        S
# 380      0          A/5 21173    7.2500    NaN        S
# 381      0              17764   30.6958     A7        C
# 382      0               2631    7.2250    NaN        C
# 383      0          A/4 48871   24.1500    NaN        S
# 384      0               8471    8.3625    NaN        S
# 385      0             345777    9.5000    NaN        S
# 386      0             236852   13.0000    NaN        S
# 387      0             382653    7.7500    NaN        Q
# 388      0               2621    6.4375    NaN        C
# 389      0               3411    8.7125    NaN        C
# 390      0           PC 17585   79.2000    NaN        C
# 391      0             C 4001   22.5250    NaN        S
# 392      0              27042   30.0000    A23        S
#
# [393 rows x 12 columns]

# %% [markdown]
# ¿Cuántos registros hay en el conjunto de datos?
#
# **Respuesta:** 393

# %% [markdown]
# ¿Qué variable(s) importante(s) son valores faltantes y cuántas faltan?
#
# **Respuesta:** ninguna  se tiene todo

# %%
#replace the Gender labels in the testing dataframe
testing["Gender"] = testing["Gender"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
#Use the fillna method of the testing dataframe column "Age" 
#to replace missing values with the mean of the age values.
testing["Age"].fillna(testing["Age"].mean(), inplace=True)

# %%
testing.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          916         0       2
# 1          917         1       1
# 2          918         0       3
# 3          919         1       1
# 4          920         1       3
# 5          921         0       3
# 6          922         0       3
# 7          923         0       3
# 8          924         0       3
# 9          925         0       2
#
#                                                 Name  Gender       Age  SibSp  \
# 0                    Coleridge, Mr. Reginald Charles       0  29.00000      0
# 1  Spedden, Mrs. Frederic Oakley (Margaretta Corn...       1  40.00000      1
# 2                                Windelov, Mr. Einar       0  21.00000      0
# 3                             Minahan, Miss. Daisy E       1  33.00000      1
# 4                   Wilkes, Mrs. James (Ellen Needs)       1  47.00000      1
# 5                        Abbott, Mr. Rossmore Edward       0  16.00000      1
# 6                          Karlsson, Mr. Nils August       0  22.00000      0
# 7                            Connaghton, Mr. Michael       0  31.00000      0
# 8                                 Foley, Mr. William       0  29.56569      0
# 9                  Leyson, Mr. Robert William Norman       0  24.00000      0
#
#    Parch            Ticket      Fare Cabin Embarked
# 0      0       W./C. 14263   10.5000   NaN        S
# 1      1             16966  134.5000   E34        C
# 2      0  SOTON/OQ 3101317    7.2500   NaN        S
# 3      0             19928   90.0000   C78        Q
# 4      0            363272    7.0000   NaN        S
# 5      1         C.A. 2673   20.2500   NaN        S
# 6      0            350060    7.5208   NaN        S
# 7      0            335097    7.7500   NaN        Q
# 8      0            365235    7.7500   NaN        Q
# 9      0        C.A. 29566   10.5000   NaN        S

# %%
#create the variable X_input to hold the features that the classifier will use
X_input = testing[list(columns)].values

# %% [markdown]
# ### CONTESTAR

# %%
#apply the model to the testing data and store the result in a pandas dataframe.
#Use X_input as the argurment for the predict() method of the clf_train classifier object

target_labels = clf_train.predict(X_input)

#convert the target array into a pandas dataframe using the pd.DataFrame() method and target as argument
target_labels = pd.DataFrame({'Est_Survival':target_labels, 'Name':testing['Name']})

# %%
target_labels.head()
# Out:
#    Est_Survival                                               Name
# 0             0                    Coleridge, Mr. Reginald Charles
# 1             1  Spedden, Mrs. Frederic Oakley (Margaretta Corn...
# 2             0                                Windelov, Mr. Einar
# 3             1                             Minahan, Miss. Daisy E
# 4             0                   Wilkes, Mrs. James (Ellen Needs)

# %%
#import the numpy library as np
import numpy as np
# Load data for all passengers in the variable all_data
all_data = pd.read_csv("titanic_all.csv")
# Merging using the field Name as key, selects only the rows of the two datasets that refer to the same passenger
testing_results = pd.merge(target_labels, all_data[['Name','Survived']], on=['Name'])

# Compute the accuracy as a ratio of matching observations to total osbervations. Store this in in the variable acc.
acc = np.sum(testing_results['Est_Survival'] == testing_results['Survived']) / float(len(testing_results))
acc
# Out:
# 0.7588832487309645

# %%
all_data.head()
# Out:
#    Passenger  Survived  Pclass  \
# 0          1         1       1
# 1          2         1       1
# 2          3         0       1
# 3          4         0       1
# 4          5         0       1
#
#                                               Name  Gender      Age  SibSp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                   Allison, Master. Hudson Trevor    male   0.9167      1
# 2                     Allison, Miss. Helen Loraine  female   2.0000      1
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
#
#    Parch  Ticket      Fare    Cabin Embarked
# 0      0   24160  211.3375       B5        S
# 1      2  113781  151.5500  C22 C26        S
# 2      2  113781  151.5500  C22 C26        S
# 3      2  113781  151.5500  C22 C26        S
# 4      2  113781  151.5500  C22 C26        S

# %% [markdown]
# ### Parte 3: Evaluar el modelo del árbol de decisiones

# %%
#import the titanic_all.csv file into a dataframe called all_data. Specify the list of columns to import.
all_data = pd.read_csv("titanic_all.csv", usecols=['Survived','Pclass','Gender','Age','SibSp','Fare'])
all_data.head()
# Out:
#    Survived  Pclass  Gender      Age  SibSp      Fare
# 0         1       1  female  29.0000      0  211.3375
# 1         1       1    male   0.9167      1  151.5500
# 2         0       1  female   2.0000      1  151.5500
# 3         0       1    male  30.0000      1  151.5500
# 4         0       1  female  25.0000      1  151.5500

# %% [markdown]
# ¿Cuántos registros hay en el conjunto de datos?
#
# **Respuesta:** 1308

# %% [markdown]
# ¿Qué variable(s) importante(s) son valores faltantes y cuántas faltan?
#
# **Respuesta:** ninguna no son nesesarias para evalvuar el arbol

# %%
all_data["Gender"] = all_data["Gender"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
all_data["Age"].fillna(training["Age"].mean(), inplace=True)
all_data.head()
# Out:
#    Survived  Pclass  Gender      Age  SibSp      Fare
# 0         1       1       1  29.0000      0  211.3375
# 1         1       1       0   0.9167      1  151.5500
# 2         0       1       1   2.0000      1  151.5500
# 3         0       1       0  30.0000      1  151.5500
# 4         0       1       1  25.0000      1  151.5500

# %%
#Import train_test_split() from the sklearn.model_selection libary 
from sklearn.model_selection import train_test_split

#create the input and target variables as uppercase X and lowercase y. Reuse the columns variable.
X = all_data[list(columns)].values
y = all_data["Survived"].values

#generate the four testing and training data arrays with the train_test_split() method
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.40, random_state=0)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
X_train
# Out:
# array([[ 8.05      ,  3.        ,  1.        , 18.        ,  0.        ],
#        [76.7292    ,  1.        ,  0.        , 48.        ,  1.        ],
#        [35.        ,  1.        ,  0.        , 29.97086721,  0.        ],
#        ...,
#        [ 7.7333    ,  3.        ,  1.        , 29.97086721,  0.        ],
#        [36.75      ,  2.        ,  1.        , 20.        ,  0.        ],
#        [15.5       ,  3.        ,  1.        , 32.        ,  1.        ]])

# %%
#create the training decision tree object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)

#fit the training model using the input and target variables
clf_train = clf_train.fit(X_train, y_train)

# %%
#score the model on the two datasets and store the scores in variables. Convert the scores to strings using str()
train_score = str(clf_train.score(X_train,y_train))
test_score = str(clf_train.score(X_test,y_test))

#output the values in a test string
print('Training score = '+ train_score+' Testing score = '+test_score)
# Out:
# Training score = 0.8201530612244898 Testing score = 0.8053435114503816

# %% [markdown]
# ### Hacer de Tarea
#
# Elimina  valores de edad faltantes
#
# use un  promedio para reemplazar los valores de edad faltantes puede afectar la precisión del modelo. la solución para esto puede fue  eliminar todas las observaciones con valores de edad faltantes.

# %%
training = pd.read_csv("titanic-train.csv")
training["Gender"] = training["Gender"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
training.head()
# Out:
#    PassengerId  Survived  Pclass                         Name  Gender   Age  \
# 0            1         0       1       Davidson, Mr. Thornton       0  31.0
# 1            2         0       3              Asim, Mr. Adola       0  35.0
# 2            3         0       3           Nankoff, Mr. Minko       0   NaN
# 3            4         0       1     Thayer, Mr. John Borland       0  49.0
# 4            5         0       3  Strandberg, Miss. Ida Sofia       1  22.0
#
#    SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      1      0          F.C. 12750   52.0000   B71        S
# 1      0      0  SOTON/O.Q. 3101310    7.0500   NaN        S
# 2      0      0              349218    7.8958   NaN        S
# 3      1      1               17421  110.8833   C68        C
# 4      0      0                7553    9.8375   NaN        S

# %%
training.dropna(subset=['Age'], inplace=True)

# %%
training
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       1
# 1              2         0       3
# 3              4         0       1
# 4              5         0       3
# 5              6         0       2
# 6              7         0       3
# 7              8         0       3
# 11            12         0       2
# 12            13         1       1
# 13            14         1       1
# 15            16         1       3
# 16            17         0       2
# 17            18         1       1
# 20            21         0       3
# 21            22         1       3
# 22            23         1       1
# 23            24         0       3
# 24            25         0       3
# 25            26         1       1
# 26            27         1       2
# 27            28         0       3
# 28            29         0       3
# 30            31         0       3
# 31            32         0       2
# 34            35         0       3
# 35            36         1       2
# 36            37         0       3
# 38            39         0       3
# 39            40         0       3
# 41            42         0       3
# ..           ...       ...     ...
# 875          876         0       3
# 876          877         0       2
# 878          879         0       3
# 879          880         0       3
# 880          881         0       3
# 881          882         0       3
# 882          883         0       3
# 885          886         0       1
# 886          887         0       2
# 887          888         0       1
# 888          889         0       3
# 889          890         1       3
# 890          891         0       3
# 893          894         0       3
# 894          895         0       2
# 895          896         1       1
# 896          897         1       3
# 897          898         0       3
# 898          899         1       2
# 899          900         1       1
# 901          902         0       3
# 902          903         0       3
# 903          904         0       3
# 904          905         1       1
# 905          906         1       1
# 907          908         0       2
# 909          910         0       3
# 910          911         0       3
# 912          913         0       3
# 913          914         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                               Davidson, Mr. Thornton       0  31.0      1
# 1                                      Asim, Mr. Adola       0  35.0      0
# 3                             Thayer, Mr. John Borland       0  49.0      1
# 4                          Strandberg, Miss. Ida Sofia       1  22.0      0
# 5                                 Bowenur, Mr. Solomon       0  42.0      0
# 6                          Bowen, Mr. David John "Dai"       0  21.0      0
# 7                                       Assam, Mr. Ali       0  23.0      0
# 11                           Maybery, Mr. Frank Hubert       0  40.0      0
# 12                     Greenfield, Mr. William Bertram       0  23.0      0
# 13       Snyder, Mrs. John Pillsbury (Nelle Stevenson)       1  23.0      1
# 15                                    Nakid, Mr. Sahid       0  20.0      1
# 16                           Stokes, Mr. Philip Joseph       0  25.0      0
# 17      Lines, Mrs. Ernest H (Elizabeth Lindsey James)       1  51.0      0
# 20                                Zabour, Miss. Hileni       1  14.5      1
# 21                                     Chip, Mr. Chang       0  32.0      0
# 22                                Cleaver, Miss. Alice       1  22.0      0
# 23                                 Canavan, Miss. Mary       1  21.0      0
# 24                             Moen, Mr. Sigurd Hansen       0  25.0      0
# 25                           Harper, Mr. Henry Sleeper       0  48.0      1
# 26                          Quick, Miss. Winifred Vera       1   8.0      1
# 27                           Rice, Master. George Hugh       0   8.0      4
# 28                        Berglund, Mr. Karl Ivar Sven       0  22.0      0
# 30                     Brocklebank, Mr. William Alfred       0  35.0      0
# 31          Sedgwick, Mr. Charles Frederick Waddington       0  25.0      0
# 34                           Goldsmith, Mr. Frank John       0  33.0      1
# 35   Phillips, Miss. Kate Florence ("Mrs Kate Louis...       1  19.0      0
# 36                    Holm, Mr. John Fredrik Alexander       0  43.0      0
# 38                           Salonen, Mr. Johan Werner       0  39.0      0
# 39                            Olsen, Mr. Henry Margido       0  28.0      0
# 41                                  Mangan, Miss. Mary       1  30.5      0
# ..                                                 ...     ...   ...    ...
# 875                                   Saad, Mr. Khalil       0  25.0      0
# 876                               Moraweck, Dr. Ernest       0  54.0      0
# 878                          Nysveen, Mr. Johan Hansen       0  61.0      0
# 879                                   Dimic, Mr. Jovan       0  42.0      0
# 880                               Christmann, Mr. Emil       0  29.0      0
# 881               Vestrom, Miss. Hulda Amanda Adolfina       1  14.0      0
# 882                                  Elias, Mr. Joseph       0  39.0      0
# 885                           Julian, Mr. Henry Forbes       0  50.0      0
# 886                          Myles, Mr. Thomas Francis       0  62.0      0
# 887                       McCaffry, Mr. Thomas Francis       0  46.0      0
# 888                                  Kink, Mr. Vincenz       0  26.0      2
# 889                         Aks, Mrs. Sam (Leah Rosen)       1  18.0      0
# 890                                    Cor, Mr. Bartol       0  35.0      0
# 893                            Boulos, Miss. Nourelain       1   9.0      1
# 894                  Byles, Rev. Thomas Roussel Davids       0  42.0      0
# 895                        Compton, Miss. Sara Rebecca       1  39.0      1
# 896                           Kink-Heilmann, Mr. Anton       0  29.0      3
# 897       Riihivouri, Miss. Susanna Juhantytar "Sanni"       1  22.0      0
# 898                Troutt, Miss. Edwina Celia "Winnie"       1  27.0      0
# 899                    Schabert, Mrs. Paul (Emma Mock)       1  35.0      1
# 901                                Yasbeck, Mr. Antoni       0  27.0      1
# 902     Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)       1  36.0      0
# 903                           Larsson, Mr. Bengt Edvin       0  29.0      0
# 904                       Hoyt, Mr. Frederick Maxfield       0  38.0      1
# 905                             Lesurer, Mr. Gustave J       0  35.0      0
# 907                      Fillbrook, Mr. Joseph Charles       0  18.0      0
# 909                           Crease, Mr. Ernest James       0  19.0      0
# 910                                Baccos, Mr. Raffull       0  20.0      0
# 912                                   Wirz, Mr. Albert       0  27.0      0
# 913                                Johnson, Mr. Alfred       0  49.0      0
#
#      Parch              Ticket      Fare    Cabin Embarked
# 0        0          F.C. 12750   52.0000      B71        S
# 1        0  SOTON/O.Q. 3101310    7.0500      NaN        S
# 3        1               17421  110.8833      C68        C
# 4        0                7553    9.8375      NaN        S
# 5        0              211535   13.0000      NaN        S
# 6        0               54636   16.1000      NaN        S
# 7        0  SOTON/O.Q. 3101309    7.0500      NaN        S
# 11       0              239059   16.0000      NaN        S
# 12       1            PC 17759   63.3583  D10 D12        C
# 13       0               21228   82.2667      B45        S
# 15       1                2653   15.7417      NaN        C
# 16       0        F.C.C. 13540   10.5000      NaN        S
# 17       1            PC 17592   39.4000      D28        S
# 20       0                2665   14.4542      NaN        C
# 21       0                1601   56.4958      NaN        S
# 22       0              113781  151.5500      NaN        S
# 23       0              364846    7.7500      NaN        Q
# 24       0              348123    7.6500    F G73        S
# 25       0            PC 17572   76.7292      D33        C
# 26       1               26360   26.0000      NaN        S
# 27       1              382652   29.1250      NaN        Q
# 28       0             PP 4348    9.3500      NaN        S
# 30       0              364512    8.0500      NaN        S
# 31       0              244361   13.0000      NaN        S
# 34       1              363291   20.5250      NaN        S
# 35       0              250655   26.0000      NaN        S
# 36       0              C 7075    6.4500      NaN        S
# 38       0             3101296    7.9250      NaN        S
# 39       0              C 4001   22.5250      NaN        S
# 41       0              364850    7.7500      NaN        Q
# ..     ...                 ...       ...      ...      ...
# 875      0                2672    7.2250      NaN        C
# 876      0               29011   14.0000      NaN        S
# 878      0              345364    6.2375      NaN        S
# 879      0              315088    8.6625      NaN        S
# 880      0              343276    8.0500      NaN        S
# 881      0              350406    7.8542      NaN        S
# 882      2                2675    7.2292      NaN        C
# 885      0              113044   26.0000      E60        S
# 886      0              240276    9.6875      NaN        Q
# 887      0               13050   75.2417       C6        C
# 888      0              315151    8.6625      NaN        S
# 889      1              392091    9.3500      NaN        S
# 890      0              349230    7.8958      NaN        S
# 893      1                2678   15.2458      NaN        C
# 894      0              244310   13.0000      NaN        S
# 895      1            PC 17756   83.1583      E49        C
# 896      1              315153   22.0250      NaN        S
# 897      0             3101295   39.6875      NaN        S
# 898      0               34218   10.5000     E101        S
# 899      0               13236   57.7500      C28        C
# 901      0                2659   14.4542      NaN        C
# 902      2              350405   12.1833      NaN        S
# 903      0              347067    7.7750      NaN        S
# 904      0               19943   90.0000      C93        S
# 905      0            PC 17755  512.3292     B101        C
# 907      0          C.A. 15185   10.5000      NaN        S
# 909      0           S.P. 3464    8.1583      NaN        S
# 910      0                2679    7.2250      NaN        C
# 912      0              315154    8.6625      NaN        S
# 913      0                LINE    0.0000      NaN        S
#
# [738 rows x 12 columns]

# %%
y_target = training["Survived"].values

# %%
columns = ["Fare", "Pclass", "Gender", "Age", "SibSp"]
#create the variable to hold the features that the classifier will use
X_input = training[list(columns)].values

# %%
#import the tree module from the sklearn library
from sklearn import tree

#create clf_train as a decision tree classifier object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)

#train the model using the fit() method of the decision tree object. 
#Supply the method with the input variable X_input and the target variable y_target
clf_train = clf_train.fit(X_input, y_target)

# %%
clf_train.score(X_input,y_target)
# Out:
# 0.8252032520325203

# %%
clasificacion=['No vive', 'vive']

# %%
import sklearn
#from sklearn.externals.six import StringIO
with open("titanic2.dot", 'w') as f:
  f = tree.export_graphviz(clf_train, out_file=f, feature_names=columns, class_names=clasificacion)

# %%
# !dot -Tpng titanic2.dot -o titanic2.png

# %%
from IPython.display import Image

#display the decison tree graphic
Image("titanic2.png")

# %%
import graphviz
dot_data = tree.export_graphviz(clf_train, out_file=None,   
                         class_names=clasificacion,
                         feature_names=columns,
                         filled=True, rounded=True,
                         special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render("TitanicColor", format='png')
graph

# %% [markdown]
# ##### Conclucion.
#
#  Que hay datos mas rapidos  que se pueden usar mejor, usando un reguimen de lo que se quiere saber asi aroje datos mas esactos de ciertas caracteriticas como lo que desaba saber aqui.
